# %% [markdown]
# # Testing
#
# This is a notebook just to test with my Github repository.

# %%
print('Hello world! Python')

# %%
# %sql
select 'Hello world! SQL'

# %%
# %fs ls

# %%
dbutils.fs.help()
